# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import pandas as pd

# %%
import os
import json

# %% [markdown]
# ## READING CSV FILE

# %%
csv_path="C:\\Users\\Asaithambi\\Documents\\kayal\\customers-100.csv"

# %%
df_csv = pd.read_csv(csv_path)

# %%
print(df_csv.head())
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %% [markdown]
# ## READING JSON FILE

# %%
json_path="C:\\Users\\Asaithambi\\Documents\\kayal\\sample2.json"

# %%
with open(json_path,"r")as f:
    raw_data1 = json.load(f)

# %%
df_json=pd.json_normalize(raw_data1)

# %%
df_json
# Out:
#                               shoppingList.groceries  \
# 0  [{'item': 'Apples', 'quantity': 3, 'unit': 'lb...
#
#                            shoppingList.personalCare  \
# 0  [{'item': 'Toothpaste', 'quantity': 2, 'unit':...
#
#                          shoppingList.householdItems
# 0  [{'item': 'Paper Towels', 'quantity': 4, 'unit...

# %% [markdown]
# ## READING PARQUET FILE

# %%
pip install pyarrow

# %%
parquet_path="C:\\Users\\Asaithambi\\Documents\\kayal\\house-price.parquet"

# %%
df_parquet=pd.read_parquet(parquet_path,engine="pyarrow")

# %%
df_parquet
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...
